# %% [markdown]
# # B2_Extract_Transform

# %% [markdown]
# This workbook **extracts** and **transforms** the data for the model.
#
# This entails the following steps:
#
# | No.    | Step                                          |
# | :------| :---------------------------------------------|
# | B2.1   | Import Libraries                              |
# | B2.2   | Load Combined Dataset                         |
# | B2.3   | Extract and Rename Images from Subfolders     |
# | B2.4   | Delete Empty Subfolders                       |

# %% [markdown]
# ## B2.1 Import Libraries

# %%
#Import libraries
import shutil
import os
from os import listdir
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import pickle

# %% [markdown]
# ## B2.2 Load Combined Dataset

# %%
#Read csv
combined = pd.read_csv('../deepfashionextract2/combined.csv')
#Try dataset
combined.iloc[0,3]
# Out:
# '../deepfashionextract2/img/top/Abstract_Floral_Fringe_Crop_Top/img_00000001.jpg'

# %%
#Find out numbers of images
combined.groupby('category')['image_name'].count()
# Out:
# category
# dress    500
# skirt    500
# top      500
# Name: image_name, dtype: int64

# %% [markdown]
# ## B2.3 Extract and Rename Images from Subfolders

# %% [markdown]
# The images are extracted from the subfolders, and renamed in also carrying the **name of the subfolder**.
# \
# This creates a **unique identifier**, since previously images in different folders had the same name.
# \
# Due to the bulk of the data the renaming occurs in **batches.**

# %%
#Rename in dirName1
dirName1 = '../deepfashionextract2/img/top'

for root, dirs, files in os.walk(dirName1):
        
    for dr in dirs:
        dr_root = root + '/' + dr
            
        for file in os.listdir(dr_root):
            file_root = dr_root + '/' + file
            dst = dirName1 + '/' + dr + '_' + file
                
            for l in range(500):
                if combined.iloc[l,3]==file_root: 
                    try:
                        os.rename(file_root, dst) 
                        print(f'File', dst, 'now renamed') 
                    except FileExistsError:
                        print(f'File', dst, 'already renamed')

# %%
#Rename in dirName2
dirName2 = '../deepfashionextract2/img/skirt'

for root, dirs, files in os.walk(dirName2):
        
    for dr in dirs:
        dr_root = root + '/' + dr
            
        for file in os.listdir(dr_root):
            file_root = dr_root + '/' + file
            dst = dirName2 + '/' + dr + '_' + file
                
            for l in range(500):
                if combined.iloc[l,3]==file_root: 
                    try:
                        os.rename(file_root, dst) 
                        print(f'File', dst, 'now renamed') 
                    except FileExistsError:
                        print(f'File', dst, 'already renamed')

# %%
#Rename in dirName3
dirName3 = '../deepfashionextract2/img/dress'

for root, dirs, files in os.walk(dirName3):
        
    for dr in dirs:
        dr_root = root + '/' + dr
            
        for file in os.listdir(dr_root):
            file_root = dr_root + '/' + file
            dst = dirName3 + '/' + dr + '_' + file
                
            for l in range(500):
                if combined.iloc[l,3]==file_root: 
                    try:
                        os.rename(file_root, dst) 
                        print(f'File', dst, 'now renamed') 
                    except FileExistsError:
                        print(f'File', dst, 'already renamed')

# %% [markdown]
# ## B2.4 Delete Unnecessary Subfolders

# %%
#Delete unnecessary folders 
list = [dirName1, dirName2, dirName3]
for i in list:
    for root, dirs, files in os.walk(i):
        for dr in dirs:
            try:
                shutil.rmtree(os.path.join(root, dr))
            except Exception as e:
                pass

# %%
#Find number of images
list = [dirName1, dirName2, dirName3]
for i in list:
    print(len(os.listdir(i)))
# Out:
# 500
# 500
# 500

# %%
os.listdir(dirName1)
# Out:
# ['Abstract_Floral_Fringe_Crop_Top_img_00000001.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000002.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000003.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000004.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000005.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000006.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000007.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000008.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000009.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000010.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000011.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000012.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000013.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000014.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000015.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000016.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000017.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000018.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000019.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000020.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000021.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000022.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000023.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000024.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000025.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000026.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000027.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000028.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000029.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000030.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000031.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000032.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000033.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000034.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000035.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000036.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000037.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000038.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000039.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000040.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000041.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000042.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000043.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000044.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000045.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000046.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000047.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000048.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000049.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000050.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000051.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000052.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000053.jpg',
#  'Abstract_Floral_Fringe_Crop_Top_img_00000054.jpg',
#  'Abstract_Floral_Print_Top_img_00000001.jpg',
#  'Abstract_Floral_Print_Top_img_00000002.jpg',
#  'Abstract_Floral_Print_Top_img_00000003.jpg',
#  'Abstract_Floral_Print_Top_img_00000004.jpg',
#  'Abstract_Floral_Print_Top_img_00000005.jpg',
#  'Abstract_Floral_Print_Top_img_00000006.jpg',
#  'Abstract_Floral_Print_Top_img_00000007.jpg',
#  'Abstract_Floral_Print_Top_img_00000008.jpg',
#  'Abstract_Floral_Print_Top_img_00000009.jpg',
#  'Abstract_Floral_Print_Top_img_00000010.jpg',
#  'Abstract_Floral_Print_Top_img_00000011.jpg',
#  'Abstract_Floral_Print_Top_img_00000012.jpg',
#  'Abstract_Floral_Print_Top_img_00000013.jpg',
#  'Abstract_Floral_Print_Top_img_00000014.jpg',
#  'Abstract_Floral_Print_Top_img_00000015.jpg',
#  'Abstract_Floral_Print_Top_img_00000016.jpg',
#  'Abstract_Floral_Print_Top_img_00000017.jpg',
#  'Abstract_Floral_Print_Top_img_00000018.jpg',
#  'Abstract_Floral_Print_Top_img_00000019.jpg',
#  'Abstract_Floral_Print_Top_img_00000020.jpg',
#  'Abstract_Floral_Print_Top_img_00000021.jpg',
#  'Abstract_Floral_Print_Top_img_00000022.jpg',
#  'Abstract_Floral_Print_Top_img_00000023.jpg',
#  'Abstract_Floral_Print_Top_img_00000024.jpg',
#  'Abstract_Floral_Print_Top_img_00000025.jpg',
#  'Abstract_Floral_Print_Top_img_00000026.jpg',
#  'Abstract_Floral_Print_Top_img_00000027.jpg',
#  'Abstract_Floral_Print_Top_img_00000028.jpg',
#  'Abstract_Floral_Print_Top_img_00000029.jpg',
#  'Abstract_Floral_Print_Top_img_00000030.jpg',
#  'Abstract_Floral_Print_Top_img_00000031.jpg',
#  'Abstract_Floral_Print_Top_img_00000032.jpg',
#  'Abstract_Floral_Print_Top_img_00000033.jpg',
#  'Abstract_Floral_Print_Top_img_00000034.jpg',
#  'Abstract_Floral_Print_Top_img_00000035.jpg',
#  'Abstract_Floral_Print_Top_img_00000036.jpg',
#  'Abstract_Floral_Print_Top_img_00000037.jpg',
#  'Abstract_Floral_Print_Top_img_00000038.jpg',
#  'Abstract_Floral_Print_Top_img_00000039.jpg',
#  'Abstract_Floral_Print_Top_img_00000040.jpg',
#  'Abstract_Floral_Print_Top_img_00000041.jpg',
#  'Abstract_Floral_Print_Top_img_00000042.jpg',
#  'Abstract_Floral_Print_Top_img_00000043.jpg',
#  'Abstract_Floral_Print_Top_img_00000044.jpg',
#  'Abstract_Floral_Print_Top_img_00000045.jpg',
#  'Abstract_Floral_Print_Top_img_00000046.jpg',
#  'Abstract_Print_Boxy_Top_img_00000001.jpg',
#  'Abstract_Print_Boxy_Top_img_00000002.jpg',
#  'Abstract_Print_Boxy_Top_img_00000003.jpg',
#  'Abstract_Print_Boxy_Top_img_00000004.jpg',
#  'Abstract_Print_Boxy_Top_img_00000005.jpg',
#  'Abstract_Print_Boxy_Top_img_00000006.jpg',
#  'Abstract_Print_Boxy_Top_img_00000007.jpg',
#  'Abstract_Print_Boxy_Top_img_00000008.jpg',
#  'Abstract_Print_Boxy_Top_img_00000009.jpg',
#  'Abstract_Print_Boxy_Top_img_00000010.jpg',
#  'Abstract_Print_Boxy_Top_img_00000011.jpg',
#  'Abstract_Print_Boxy_Top_img_00000012.jpg',
#  'Abstract_Print_Boxy_Top_img_00000013.jpg',
#  'Abstract_Print_Boxy_Top_img_00000014.jpg',
#  'Abstract_Print_Boxy_Top_img_00000015.jpg',
#  'Abstract_Print_Boxy_Top_img_00000016.jpg',
#  'Abstract_Print_Boxy_Top_img_00000017.jpg',
#  'Abstract_Print_Boxy_Top_img_00000018.jpg',
#  'Abstract_Print_Boxy_Top_img_00000019.jpg',
#  'Abstract_Print_Bustier_Top_img_00000001.jpg',
#  'Abstract_Print_Bustier_Top_img_00000002.jpg',
#  'Abstract_Print_Bustier_Top_img_00000003.jpg',
#  'Abstract_Print_Bustier_Top_img_00000004.jpg',
#  'Abstract_Print_Bustier_Top_img_00000005.jpg',
#  'Abstract_Print_Bustier_Top_img_00000006.jpg',
#  'Abstract_Print_Bustier_Top_img_00000007.jpg',
#  'Abstract_Print_Bustier_Top_img_00000008.jpg',
#  'Abstract_Print_Bustier_Top_img_00000009.jpg',
#  'Abstract_Print_Bustier_Top_img_00000010.jpg',
#  'Abstract_Print_Bustier_Top_img_00000011.jpg',
#  'Abstract_Print_Bustier_Top_img_00000012.jpg',
#  'Abstract_Print_Bustier_Top_img_00000013.jpg',
#  'Abstract_Print_Bustier_Top_img_00000014.jpg',
#  'Abstract_Print_Bustier_Top_img_00000015.jpg',
#  'Abstract_Print_Bustier_Top_img_00000016.jpg',
#  'Abstract_Print_Bustier_Top_img_00000017.jpg',
#  'Abstract_Print_Bustier_Top_img_00000018.jpg',
#  'Abstract_Print_Bustier_Top_img_00000019.jpg',
#  'Abstract_Print_Bustier_Top_img_00000020.jpg',
#  'Abstract_Print_Bustier_Top_img_00000021.jpg',
#  'Abstract_Print_Bustier_Top_img_00000022.jpg',
#  'Abstract_Print_Bustier_Top_img_00000023.jpg',
#  'Abstract_Print_Bustier_Top_img_00000024.jpg',
#  'Abstract_Print_Bustier_Top_img_00000025.jpg',
#  'Abstract_Print_Bustier_Top_img_00000026.jpg',
#  'Abstract_Print_Bustier_Top_img_00000027.jpg',
#  'Abstract_Print_Bustier_Top_img_00000028.jpg',
#  'Abstract_Print_Bustier_Top_img_00000029.jpg',
#  'Abstract_Print_Bustier_Top_img_00000030.jpg',
#  'Abstract_Print_Bustier_Top_img_00000031.jpg',
#  'Abstract_Print_Bustier_Top_img_00000032.jpg',
#  'Abstract_Print_Bustier_Top_img_00000033.jpg',
#  'Abstract_Print_Bustier_Top_img_00000034.jpg',
#  'Abstract_Print_Bustier_Top_img_00000035.jpg',
#  'Abstract_Print_Bustier_Top_img_00000036.jpg',
#  'Abstract_Print_Bustier_Top_img_00000037.jpg',
#  'Abstract_Print_Bustier_Top_img_00000038.jpg',
#  'Abstract_Print_Bustier_Top_img_00000039.jpg',
#  'Abstract_Print_Bustier_Top_img_00000040.jpg',
#  'Abstract_Print_Bustier_Top_img_00000041.jpg',
#  'Abstract_Print_Bustier_Top_img_00000042.jpg',
#  'Abstract_Print_Bustier_Top_img_00000043.jpg',
#  'Abstract_Print_Bustier_Top_img_00000044.jpg',
#  'Abstract_Print_Bustier_Top_img_00000045.jpg',
#  'Abstract_Print_Bustier_Top_img_00000046.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000001.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000002.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000003.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000004.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000005.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000006.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000007.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000008.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000009.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000010.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000011.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000012.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000013.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000014.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000015.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000016.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000017.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000018.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000019.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000020.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000021.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000022.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000023.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000024.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000025.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000026.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000027.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000028.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000029.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000030.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000031.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000032.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000033.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000034.jpg',
#  'Abstract_Print_Colorblock_Top_img_00000035.jpg',
#  'Abstract_Striped_Top_img_00000001.jpg',
#  'Abstract_Striped_Top_img_00000002.jpg',
#  'Abstract_Striped_Top_img_00000003.jpg',
#  'Abstract_Striped_Top_img_00000004.jpg',
#  'Abstract_Striped_Top_img_00000005.jpg',
#  'Abstract_Striped_Top_img_00000006.jpg',
#  'Abstract_Striped_Top_img_00000007.jpg',
#  'Abstract_Striped_Top_img_00000008.jpg',
#  'Abstract_Striped_Top_img_00000009.jpg',
#  'Abstract_Striped_Top_img_00000010.jpg',
#  'Abstract_Striped_Top_img_00000011.jpg',
#  'Abstract_Striped_Top_img_00000012.jpg',
#  'Abstract_Striped_Top_img_00000013.jpg',
#  'Abstract_Striped_Top_img_00000014.jpg',
#  'Abstract_Striped_Top_img_00000015.jpg',
#  'Abstract_Striped_Top_img_00000016.jpg',
#  'Abstract_Striped_Top_img_00000017.jpg',
#  'Abstract_Striped_Top_img_00000018.jpg',
#  'Abstract_Striped_Top_img_00000019.jpg',
#  'Abstract_Striped_Top_img_00000020.jpg',
#  'Abstract_Striped_Top_img_00000021.jpg',
#  'Abstract_Striped_Top_img_00000022.jpg',
#  'Abstract_Striped_Top_img_00000023.jpg',
#  'Abstract_Striped_Top_img_00000024.jpg',
#  'Abstract_Striped_Top_img_00000025.jpg',
#  'Abstract_Striped_Top_img_00000026.jpg',
#  'Abstract_Striped_Top_img_00000027.jpg',
#  'Abstract_Striped_Top_img_00000028.jpg',
#  'Abstract_Striped_Top_img_00000029.jpg',
#  'Abstract_Striped_Top_img_00000030.jpg',
#  'Abstract_Striped_Top_img_00000031.jpg',
#  'Abstract_Striped_Top_img_00000032.jpg',
#  'Abstract_Striped_Top_img_00000033.jpg',
#  'Abstract_Striped_Top_img_00000034.jpg',
#  'Abstract_Striped_Top_img_00000035.jpg',
#  'Abstract_Striped_Top_img_00000036.jpg',
#  'Abstract_Striped_Top_img_00000037.jpg',
#  'Abstract_Striped_Top_img_00000038.jpg',
#  'Abstract_Striped_Top_img_00000039.jpg',
#  'Abstract_Striped_Top_img_00000040.jpg',
#  'Abstract_Striped_Top_img_00000041.jpg',
#  'Abstract_Striped_Top_img_00000042.jpg',
#  'Abstract_Striped_Top_img_00000043.jpg',
#  'Abstract_Striped_Top_img_00000044.jpg',
#  'Abstract_Striped_Top_img_00000045.jpg',
#  'Abstract_Striped_Top_img_00000046.jpg',
#  'Barbie_Tank_Top_img_00000001.jpg',
#  'Barbie_Tank_Top_img_00000002.jpg',
#  'Barbie_Tank_Top_img_00000003.jpg',
#  'Barbie_Tank_Top_img_00000004.jpg',
#  'Barbie_Tank_Top_img_00000005.jpg',
#  'Barbie_Tank_Top_img_00000006.jpg',
#  'Barbie_Tank_Top_img_00000007.jpg',
#  'Barbie_Tank_Top_img_00000008.jpg',
#  'Barbie_Tank_Top_img_00000009.jpg',
#  'Barbie_Tank_Top_img_00000010.jpg',
#  'Barbie_Tank_Top_img_00000011.jpg',
#  'Barbie_Tank_Top_img_00000012.jpg',
#  'Barbie_Tank_Top_img_00000013.jpg',
#  'Barbie_Tank_Top_img_00000014.jpg',
#  'Barbie_Tank_Top_img_00000015.jpg',
#  'Barbie_Tank_Top_img_00000016.jpg',
#  'Barbie_Tank_Top_img_00000017.jpg',
#  'Barbie_Tank_Top_img_00000018.jpg',
#  'Barbie_Tank_Top_img_00000019.jpg',
#  'Barbie_Tank_Top_img_00000020.jpg',
#  'Barbie_Tank_Top_img_00000021.jpg',
#  'Barbie_Tank_Top_img_00000022.jpg',
#  'Barbie_Tank_Top_img_00000023.jpg',
#  'Barbie_Tank_Top_img_00000024.jpg',
#  'Barbie_Tank_Top_img_00000025.jpg',
#  'Barbie_Tank_Top_img_00000026.jpg',
#  'Barbie_Tank_Top_img_00000027.jpg',
#  'Barbie_Tank_Top_img_00000028.jpg',
#  'Barbie_Tank_Top_img_00000029.jpg',
#  'Barbie_Tank_Top_img_00000030.jpg',
#  'Barbie_Tank_Top_img_00000031.jpg',
#  'Barbie_Tank_Top_img_00000032.jpg',
#  'Barbie_Tank_Top_img_00000033.jpg',
#  'Barbie_Tank_Top_img_00000034.jpg',
#  'Barbie_Tank_Top_img_00000035.jpg',
#  'Barbie_Tank_Top_img_00000036.jpg',
#  'Barbie_Tank_Top_img_00000037.jpg',
#  'Barbie_Tank_Top_img_00000038.jpg',
#  'Barbie_Tank_Top_img_00000039.jpg',
#  'Barbie_Tank_Top_img_00000040.jpg',
#  'Barbie_Tank_Top_img_00000041.jpg',
#  'Barbie_Tank_Top_img_00000042.jpg',
#  'Barbie_Tank_Top_img_00000043.jpg',
#  'Barbie_Tank_Top_img_00000044.jpg',
#  'Barbie_Tank_Top_img_00000045.jpg',
#  'Barbie_Tank_Top_img_00000046.jpg',
#  'Barbie_Tank_Top_img_00000047.jpg',
#  'Barbie_Tank_Top_img_00000048.jpg',
#  'Barbie_Tank_Top_img_00000049.jpg',
#  'Barbie_Tank_Top_img_00000050.jpg',
#  'Barbie_Tank_Top_img_00000051.jpg',
#  'Barbie_Tank_Top_img_00000052.jpg',
#  'Barbie_Tank_Top_img_00000053.jpg',
#  'Barbie_Tank_Top_img_00000054.jpg',
#  'Barbie_Tank_Top_img_00000055.jpg',
#  'Barbie_Tank_Top_img_00000056.jpg',
#  'Barbie_Tank_Top_img_00000057.jpg',
#  'Barbie_Tank_Top_img_00000058.jpg',
#  'Barbie_Tank_Top_img_00000059.jpg',
#  'Barbie_Tank_Top_img_00000060.jpg',
#  'Barbie_Tank_Top_img_00000061.jpg',
#  'Barbie_Tank_Top_img_00000062.jpg',
#  'Barbie_Tank_Top_img_00000063.jpg',
#  'Barbie_Tank_Top_img_00000064.jpg',
#  'Barbie_Tank_Top_img_00000065.jpg',
#  'Barbie_Tank_Top_img_00000066.jpg',
#  'Barbie_Tank_Top_img_00000067.jpg',
#  'Barbie_Tank_Top_img_00000068.jpg',
#  'Barbie_Tank_Top_img_00000069.jpg',
#  'Barbie_Tank_Top_img_00000070.jpg',
#  'Barbie_Tank_Top_img_00000071.jpg',
#  'Barbie_Tank_Top_img_00000072.jpg',
#  'Barbie_Tank_Top_img_00000073.jpg',
#  'Barbie_Tank_Top_img_00000074.jpg',
#  'Barbie_Tank_Top_img_00000075.jpg',
#  'Barbie_Tank_Top_img_00000076.jpg',
#  'Barbie_Tank_Top_img_00000077.jpg',
#  'Barbie_Tank_Top_img_00000078.jpg',
#  'Barbie_Tank_Top_img_00000079.jpg',
#  'Barbie_Tank_Top_img_00000080.jpg',
#  'Barbie_Tank_Top_img_00000081.jpg',
#  'Barbie_Tank_Top_img_00000082.jpg',
#  'Barbie_Tank_Top_img_00000083.jpg',
#  'Barbie_Tank_Top_img_00000084.jpg',
#  'Barbie_Tank_Top_img_00000085.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000001.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000002.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000003.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000004.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000005.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000006.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000007.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000008.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000009.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000010.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000011.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000012.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000013.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000014.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000015.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000016.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000017.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000018.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000019.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000020.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000021.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000022.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000023.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000024.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000025.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000026.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000027.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000028.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000029.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000030.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000031.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000032.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000033.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000034.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000035.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000036.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000037.jpg',
#  'Baroque-Patterned_Lace_Top_img_00000038.jpg',
#  'Beaded_Lace_Crop_Top_img_00000001.jpg',
#  'Beaded_Lace_Crop_Top_img_00000002.jpg',
#  'Beaded_Lace_Crop_Top_img_00000003.jpg',
#  'Beaded_Lace_Crop_Top_img_00000004.jpg',
#  'Beaded_Lace_Crop_Top_img_00000005.jpg',
#  'Beaded_Lace_Crop_Top_img_00000006.jpg',
#  'Beaded_Lace_Crop_Top_img_00000007.jpg',
#  'Beaded_Lace_Crop_Top_img_00000008.jpg',
#  'Beaded_Lace_Crop_Top_img_00000009.jpg',
#  'Beaded_Lace_Crop_Top_img_00000010.jpg',
#  'Beaded_Lace_Crop_Top_img_00000011.jpg',
#  'Beaded_Lace_Crop_Top_img_00000012.jpg',
#  'Beaded_Lace_Crop_Top_img_00000013.jpg',
#  'Beaded_Lace_Crop_Top_img_00000014.jpg',
#  'Beaded_Lace_Crop_Top_img_00000015.jpg',
#  'Beaded_Lace_Crop_Top_img_00000016.jpg',
#  'Beaded_Lace_Crop_Top_img_00000017.jpg',
#  'Beaded_Lace_Crop_Top_img_00000018.jpg',
#  'Beaded_Lace_Crop_Top_img_00000019.jpg',
#  'Beaded_Lace_Crop_Top_img_00000020.jpg',
#  'Beaded_Lace_Crop_Top_img_00000021.jpg',
#  'Beaded_Lace_Crop_Top_img_00000022.jpg',
#  'Beaded_Lace_Crop_Top_img_00000023.jpg',
#  'Beaded_Lace_Crop_Top_img_00000024.jpg',
#  'Beaded_Lace_Crop_Top_img_00000025.jpg',
#  'Beaded_Lace_Crop_Top_img_00000026.jpg',
#  'Beaded_Lace_Crop_Top_img_00000027.jpg',
#  'Beaded_Lace_Crop_Top_img_00000028.jpg',
#  'Beaded_Lace_Crop_Top_img_00000029.jpg',
#  'Beaded_Lace_Crop_Top_img_00000030.jpg',
#  'Beaded_Lace_Crop_Top_img_00000031.jpg',
#  'Beaded_Lace_Crop_Top_img_00000032.jpg',
#  'Beaded_Lace_Crop_Top_img_00000033.jpg',
#  'Beaded_Lace_Crop_Top_img_00000034.jpg',
#  'Beaded_Lace_Crop_Top_img_00000035.jpg',
#  'Beaded_Lace_Crop_Top_img_00000036.jpg',
#  'Beaded_Lace_Crop_Top_img_00000037.jpg',
#  'Beaded_Lace_Crop_Top_img_00000038.jpg',
#  'Beaded_Lace_Crop_Top_img_00000039.jpg',
#  'Beaded_Lace_Crop_Top_img_00000040.jpg',
#  'Beaded_Lace_Crop_Top_img_00000041.jpg',
#  'Beaded_Lace_Crop_Top_img_00000042.jpg',
#  'Beaded_Lace_Crop_Top_img_00000043.jpg',
#  'Beaded_Lace_Crop_Top_img_00000044.jpg',
#  'Beaded_Lace_Crop_Top_img_00000045.jpg',
#  'Beaded_Lace_Crop_Top_img_00000046.jpg',
#  'Beaded_Lace_Crop_Top_img_00000047.jpg',
#  'Beaded_Lace_Crop_Top_img_00000048.jpg',
#  'Beaded_Lace_Crop_Top_img_00000049.jpg',
#  'Beaded_Lace_Crop_Top_img_00000050.jpg',
#  'Beaded_Lace_Crop_Top_img_00000051.jpg',
#  'Beaded_Lace_Crop_Top_img_00000052.jpg',
#  'Beaded_Lace_Crop_Top_img_00000053.jpg',
#  'Beaded_Lace_Crop_Top_img_00000054.jpg',
#  'Beaded_Lace_Crop_Top_img_00000055.jpg',
#  'Beaded_Lace_Crop_Top_img_00000056.jpg',
#  'Beaded_Lace_Crop_Top_img_00000057.jpg',
#  'Beaded_Lace_Crop_Top_img_00000058.jpg',
#  'Beaded_Lace_Crop_Top_img_00000059.jpg',
#  'Beaded_Lace_Crop_Top_img_00000060.jpg',
#  'Beaded_Lace_Crop_Top_img_00000061.jpg',
#  'Beaded_Lace_Crop_Top_img_00000062.jpg',
#  'Boxy_Striped_Crop_Top_img_00000001.jpg',
#  'Boxy_Striped_Crop_Top_img_00000002.jpg',
#  'Boxy_Striped_Crop_Top_img_00000003.jpg',
#  'Boxy_Striped_Crop_Top_img_00000004.jpg',
#  'Boxy_Striped_Crop_Top_img_00000005.jpg',
#  'Boxy_Striped_Crop_Top_img_00000006.jpg',
#  'Boxy_Striped_Crop_Top_img_00000007.jpg',
#  'Boxy_Striped_Crop_Top_img_00000008.jpg',
#  'Boxy_Striped_Crop_Top_img_00000009.jpg',
#  'Boxy_Striped_Crop_Top_img_00000010.jpg',
#  'Boxy_Striped_Crop_Top_img_00000011.jpg',
#  'Boxy_Striped_Crop_Top_img_00000012.jpg',
#  'Boxy_Striped_Crop_Top_img_00000013.jpg',
#  'Boxy_Striped_Crop_Top_img_00000014.jpg',
#  'Boxy_Striped_Crop_Top_img_00000015.jpg',
#  'Boxy_Striped_Crop_Top_img_00000016.jpg',
#  'Boxy_Striped_Crop_Top_img_00000017.jpg',
#  'Boxy_Striped_Crop_Top_img_00000018.jpg',
#  'Boxy_Striped_Crop_Top_img_00000019.jpg',
#  'Boxy_Striped_Crop_Top_img_00000020.jpg',
#  'Boxy_Striped_Crop_Top_img_00000021.jpg',
#  'Boxy_Striped_Crop_Top_img_00000022.jpg',
#  'Boxy_Striped_Crop_Top_img_00000023.jpg',
#  'Boxy_Striped_Crop_Top_img_00000024.jpg',
#  'Boxy_Striped_Crop_Top_img_00000025.jpg',
#  'Boxy_Striped_Crop_Top_img_00000026.jpg',
#  'Boxy_Striped_Crop_Top_img_00000027.jpg',
#  'Boxy_Striped_Crop_Top_img_00000028.jpg',
#  'Boxy_Striped_Crop_Top_img_00000029.jpg',
#  'Boxy_Striped_Crop_Top_img_00000030.jpg',
#  'Boxy_Striped_Crop_Top_img_00000031.jpg',
#  'Boxy_Striped_Crop_Top_img_00000032.jpg',
#  'Boxy_Striped_Crop_Top_img_00000033.jpg',
#  'Boxy_Striped_Crop_Top_img_00000034.jpg',
#  'Boxy_Striped_Crop_Top_img_00000035.jpg',
#  'Boxy_Striped_Crop_Top_img_00000036.jpg',
#  'Boxy_Striped_Crop_Top_img_00000037.jpg',
#  'Boxy_Striped_Crop_Top_img_00000038.jpg',
#  'Boxy_Striped_Crop_Top_img_00000039.jpg',
#  'Boxy_Striped_Crop_Top_img_00000040.jpg',
#  'Boxy_Striped_Crop_Top_img_00000041.jpg',
#  'Boxy_Striped_Crop_Top_img_00000042.jpg',
#  'Boxy_Striped_Crop_Top_img_00000043.jpg',
#  'Boxy_Striped_Crop_Top_img_00000044.jpg',
#  'Boxy_Striped_Crop_Top_img_00000045.jpg',
#  'Boxy_Striped_Crop_Top_img_00000046.jpg',
#  'Boxy_Striped_Crop_Top_img_00000047.jpg',
#  'Boxy_Striped_Crop_Top_img_00000048.jpg',
#  'Boxy_Striped_Crop_Top_img_00000049.jpg',
#  'Boxy_Striped_Crop_Top_img_00000050.jpg',
#  'Boxy_Striped_Crop_Top_img_00000051.jpg',
#  'Boxy_Striped_Crop_Top_img_00000052.jpg',
#  'Boxy_Striped_Crop_Top_img_00000053.jpg',
#  'Boxy_Striped_Crop_Top_img_00000054.jpg',
#  'Boxy_Tank_Top_img_00000001.jpg',
#  'Boxy_Tank_Top_img_00000002.jpg',
#  'Boxy_Tank_Top_img_00000003.jpg',
#  'Boxy_Tank_Top_img_00000004.jpg',
#  'Boxy_Tank_Top_img_00000005.jpg',
#  'Boxy_Tank_Top_img_00000006.jpg',
#  'Boxy_Tank_Top_img_00000007.jpg',
#  'Boxy_Tank_Top_img_00000008.jpg',
#  'Boxy_Tank_Top_img_00000009.jpg',
#  'Boxy_Tank_Top_img_00000010.jpg',
#  'Boxy_Tank_Top_img_00000011.jpg',
#  'Boxy_Tank_Top_img_00000012.jpg',
#  'Boxy_Tank_Top_img_00000013.jpg',
#  'Boxy_Tank_Top_img_00000014.jpg',
#  'Boxy_Tank_Top_img_00000015.jpg']
